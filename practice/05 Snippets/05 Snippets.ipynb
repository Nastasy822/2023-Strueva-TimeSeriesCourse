# %% [markdown]
# # Анализ и прогнозирование временных рядов методами искусственного интеллекта
#
# ## **Практическая работа 5. Поиск типичных подпоследовательностей временного ряда.**

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Импорт библиотек и модулей

# %%
# !pip install matrixprofile
# Out:
# Collecting matrixprofile
#   Downloading matrixprofile-1.1.10-cp38-cp38-manylinux2010_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 1.1 MB/s eta 0:00:00a 0:00:010m
# Requirement already satisfied: numpy>=1.16.2 in /opt/poetry-venv/lib/python3.8/site-packages (from matrixprofile) (1.23.1)
# Requirement already satisfied: matplotlib>=3.0.3 in /opt/poetry-venv/lib/python3.8/site-packages (from matrixprofile) (3.7.2)
# Collecting protobuf==3.11.2 (from matrixprofile)
#   Downloading protobuf-3.11.2-cp38-cp38-manylinux1_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 1.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: scipy<2.0.0,>=1.3.2 in /opt/poetry-venv/lib/python3.8/site-packages (from matrixprofile) (1.10.1)
# Requirement already satisfied: six>=1.9 in /opt/poetry-venv/lib/python3.8/site-packages (from protobuf==3.11.2->matrixprofile) (1.16.0)
# Requirement already satisfied: setuptools in /opt/poetry-venv/lib/python3.8/site-packages (from protobuf==3.11.2->matrixprofile) (68.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/poetry-venv/lib/python3.8/site-packages (from matplotlib>=3.0.3->matrixprofile) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/poetry-venv/lib/python3.8/site-packages (from matplotlib>=3.0.3->matrixprofile) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/poetry-venv/lib/python3.8/site-packages (from matplotlib>=3.0.3->matrixprofile) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/poetry-venv/lib/python3.8/site-packages (from matplotlib>=3.0.3->matrixprofile) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/poetry-venv/lib/python3.8/site-packages (from matplotlib>=3.0.3->matrixprofile) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/poetry-venv/lib/python3.8/site-packages (from matplotlib>=3.0.3->matrixprofile) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /opt/poetry-venv/lib/python3.8/site-packages (from matplotlib>=3.0.3->matrixprofile) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/poetry-venv/lib/python3.8/site-packages (from matplotlib>=3.0.3->matrixprofile) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/poetry-venv/lib/python3.8/site-packages (from matplotlib>=3.0.3->matrixprofile) (6.0.0)
# Requirement already satisfied: zipp>=3.1.0 in /opt/poetry-venv/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.0.3->matrixprofile) (3.16.2)
# Installing collected packages: protobuf, matrixprofile
# Successfully installed matrixprofile-1.1.10 protobuf-3.11.2

# %%
import numpy as np
import matplotlib.pyplot as plt
from modules.snippets import *
from scipy import signal

# %% [markdown]
# ### **Задача 1. Поиск сниппетов одномерного временного ряда**
#
# В первой задаче необходимо выполнить поиск сниппетов одномерного временного ряда. Расмотрите приведенный ниже пример использования алгоритма SnipperFinder и визуализации полученных результатов для искуственного врменного ряда.

# %%
#Создание искусственного временного ряда
t = np.linspace(np.pi, 6 * 2 * np.pi, 3000)
ts = np.concatenate([np.sin(t), signal.sawtooth(t)])
plt.plot(ts)

# %%
#Поиск сниппетов
snp = snippets(ts, 600, 2)

# %%
#Визуализация результатов
plot_snippets(ts, snp)
# Out:
# <Axes: >

# %% [markdown]
# Далее вам предстоит самостоятельно выполнить поиск top-$k$ типичных подпоследовательностей временного ряда (сниппетов) с помощью алгоритма SnippetFinder на наборе данных PAMAP. Описание набора данных находится в [README-файле](datasets/PAMAP/readme.md).
#
# Выполните считывание временного ряда **показаний гироскопа на оси «X» (угол крена) на временном интервале от 950 сек. до 109 сек.** из файла *PAMAP.txt*, который располагается в директории *./datasets/PAMAP*. Затем выполните поиск сниппетов с помощью функции `snippets()` из модуля snippets.py.

# %%
# INSERT YOUR CODE

# %% [markdown]
# Выполните визулизацию временного ряда и найденных сниппетов с помощью функции `plot_snippets()` из модуля snippets.py.

# %%
# INSERT YOUR CODE

# %% [markdown]
# Оцените точность разметки, полученной при помощи сниппетов.

# %%
# INSERT YOUR CODE

# %% [markdown]
# ❓ Проанализируйте и изложите содержательный смысл полученных результатов.

# %% [markdown]
# ### Задача 2. Разметка многомерного временного ряда
#
# Выполните разметку многомерного временно ряда, используя **показания гироскопа по всем трем осям** из набора данных PAMAP. Используйте тот же временной интервал, что и в задаче 1.

# %%
# INSERT YOUR CODE

# %% [markdown]
# Оцените точность разметки, полученной при помощи сниппетов.

# %%
# INSERT YOUR CODE

# %% [markdown]
# ❓ Проанализируйте и изложите содержательный смысл полученных результатов. Сравните полученные разметки многомерного и одномерного рядов.

# %% [markdown]
# ## Задача 3. Подбор оптимального значения _k_

# %% [markdown]
# Разработайте программу, которая выполняет выполняет вычисление меры $change$ для различных значений $k$ с помощью алгоритма SnippetFinder. Проведите эксперименты, используя временной ряд из задания 2 (взяв 1 ≤ _k_ ≤ 9).
#
# $Change_k = \frac{ProfileArea_{k-1}}{ProfileArea_k} - 1$

# %%
# INSERT YOUR CODE

# %% [markdown]
# Выполните визуализацию результатов экспериментов в следующем виде: отображение столбчатых диаграм со значениями $ProfileArea$ и меры $change$ в зависимости от $k$.

# %%
# INSERT YOUR CODE

# %% [markdown]
# ❓ Проанализируйте и изложите содержательный смысл полученных результатов. Какое значение $k$ является наилучшим для используемого временного ряда?
